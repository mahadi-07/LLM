# %% [markdown]
# ## OpenAI

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
load_dotenv()
GLM_API_KEY=os.getenv('ZAI_API_KEY')

# %%
client = OpenAI(
    api_key=GLM_API_KEY,
    base_url="https://api.z.ai/api/coding/paas/v4"
)

response = client.chat.completions.create(
    model="glm-5.1",
    messages=[
        {"role": "user", "content": "What is the capital of Bangladesh?"}
    ],
    stream=False
)

# %%
print(response)

# %%
import json

print(json.dumps(response.model_dump(), indent=2, ensure_ascii=False))

# %% [markdown]
# ## Ollama

# %%
# !pip install ollama

# %%
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(
    model="llama3.1:8b",
    messages=[
        { 'role': 'user', 'content': 'Capital of Bangladesh?', },
    ]
)

print(response.message.content)

# %%
import json

print(json.dumps(response.model_dump(), indent=2, ensure_ascii=False))

# %% [markdown]
# ##

# %% [markdown]
# ## Lite LLM

# %%
from litellm import completion

response = completion(
    model="ollama/llama3.1:8b",
    messages=[{"content": "What is the capital of Bangladesh", "role": "user"}],
    api_base="http://localhost:11434"
)

import json

print(json.dumps(response.model_dump(), indent=2, ensure_ascii=False))
# Out:
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 from litellm import completion
#       2
# ----> 3 response = completion(
#       4     model="glm-5.1",
#       5     messages=[{"content": "What is the capital of Bangladesh", "role": "user"}],
#       6     api_base="http://localhost:4000"
#
# File ~/Downloads/llm/.venv/lib/python3.11/site-packages/litellm/utils.py:1772, in client.<locals>.wrapper(*args, **kwargs)
#    1768 if logging_obj:
#    1769     logging_obj.failure_handler(
#    1770         e, traceback_exception, start_time, end_time
#    1771     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1772 raise e
#
# File ~/Downloads/llm/.venv/lib/python3.11/site-packages/litellm/utils.py:1593, in client.<locals>.wrapper(*args, **kwargs)
#    1591         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1592 # MODEL CALL
# -> 1593 result = original_function(*args, **kwargs)
#    1594 end_time = datetime.datetime.now()
#    1595 if _is_streaming_request(
#    1596     kwargs=kwargs,
#    1597     call_type=call_type,
#    1598 ):
#
# File ~/Downloads/llm/.venv/lib/python3.11/site-packages/litellm/main.py:4420, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, enable_json_schema_validation, **kwargs)
#    4417     return response
#    4418 except Exception as e:
#    4419     ## Map to OpenAI Exception
# -> 4420     raise exception_type(
#    4421         model=model,
#    4422         custom_llm_provider=custom_llm_provider,
#    4423         original_exception=e,
#    4424         completion_kwargs=args,
#    4425         extra_kwargs=kwargs,
#    4426     )
#
# File ~/Downloads/llm/.venv/lib/python3.11/site-packages/litellm/main.py:1379, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, enable_json_schema_validation, **kwargs)
#    1377     model = deployment_id
#    1378     custom_llm_provider = "azure"
# -> 1379 model, custom_llm_provider, dynamic_api_key, api_base = get_llm_provider(
#    1380     model=model,
#    1381     custom_llm_provider=custom_llm_provider,
#    1382     api_base=api_base,
#    1383     api_key=api_key,
#    1384 )
#    1386 ## RESPONSES API BRIDGE LOGIC ## - check early and normalize model name
#    1387 responses_api_model_info, model = responses_api_bridge_check(
#    1388     model=model,
#    1389     custom_llm_provider=custom_llm_provider,
#    1390     web_search_options=web_search_options,
#    1391 )
#
# File ~/Downloads/llm/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/get_llm_provider_logic.py:529, in get_llm_provider(model, custom_llm_provider, api_base, api_key, litellm_params)
#     527 except Exception as e:
#     528     if isinstance(e, litellm.exceptions.BadRequestError):
# --> 529         raise e
#     530     else:
#     531         error_str = (
#     532             f"GetLLMProvider Exception - {str(e)}\n\noriginal model: {model}"
#     533         )
#
# File ~/Downloads/llm/.venv/lib/python3.11/site-packages/litellm/litellm_core_utils/get_llm_provider_logic.py:510, in get_llm_provider(model, custom_llm_provider, api_base, api_key, litellm_params)
#     508     error_str = f"LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model={model}\n Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers"
#     509     # maps to openai.NotFoundError, this is raised when openai does not recognize the llm
# --> 510     raise litellm.exceptions.BadRequestError(  # type: ignore
#     511         message=error_str,
#     512         model=model,
#     513         response=None,
#     514         llm_provider="",
#     515     )
#     516 if api_base is not None and not isinstance(api_base, str):
#     517     raise Exception(
#     518         "api base needs to be a string. api_base={}".format(api_base)
#     519     )
#
# BadRequestError: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=glm-5.1
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
